# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
import graphviz
from sklearn.tree import export_graphviz

# %%
data = load_breast_cancer()
dir(data)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
# data.DESCR

# %%
data.target_names
# Out:
# array(['malignant', 'benign'], dtype='<U9')

# %%
DF = pd.DataFrame(np.c_[data.data, data.target], columns=[list(data.feature_names) + ['target']])
# DF.head()
DF.tail()
# Out:
#     mean radius mean texture mean perimeter mean area mean smoothness  \
# 564       21.56        22.39         142.00    1479.0         0.11100
# 565       20.13        28.25         131.20    1261.0         0.09780
# 566       16.60        28.08         108.30     858.1         0.08455
# 567       20.60        29.33         140.10    1265.0         0.11780
# 568        7.76        24.54          47.92     181.0         0.05263
#
#     mean compactness mean concavity mean concave points mean symmetry  \
# 564          0.11590        0.24390             0.13890        0.1726
# 565          0.10340        0.14400             0.09791        0.1752
# 566          0.10230        0.09251             0.05302        0.1590
# 567          0.27700        0.35140             0.15200        0.2397
# 568          0.04362        0.00000             0.00000        0.1587
#
#     mean fractal dimension  ... worst texture worst perimeter worst area  \
# ...

# %%
(DF["target"]==1).sum(), (DF["target"]==0).sum()
# Out:
# (target    357
#  dtype: int64,
#  target    212
#  dtype: int64)

# %%
DF.shape
# Out:
# (569, 31)

# %%
X = DF.iloc[:, :-1]
Y = DF.iloc[:, -1]
X.shape, Y.shape
# Out:
# ((569, 30), (569,))

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state = 11)

# %%
clf = DecisionTreeClassifier(criterion="gini")    
clf.fit(x_train, y_train)
# Out:
# C:\Users\PARAS\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# DecisionTreeClassifier()

# %%
clf.score(x_test, y_test)
# Out:
# C:\Users\PARAS\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# 0.956140350877193

# %% [markdown]
# # Prediction

# %%
patient = np.array([data.data[21]])     #I took a random row from the dataset to check.
patient
# Out:
# array([[9.504e+00, 1.244e+01, 6.034e+01, 2.739e+02, 1.024e-01, 6.492e-02,
#         2.956e-02, 2.076e-02, 1.815e-01, 6.905e-02, 2.773e-01, 9.768e-01,
#         1.909e+00, 1.570e+01, 9.606e-03, 1.432e-02, 1.985e-02, 1.421e-02,
#         2.027e-02, 2.968e-03, 1.023e+01, 1.566e+01, 6.513e+01, 3.149e+02,
#         1.324e-01, 1.148e-01, 8.867e-02, 6.227e-02, 2.450e-01, 7.773e-02]])

# %%
pred = clf.predict(patient)

# %%
data.target_names[int(pred)]
# Out:
# 'benign'

# %%
# clf.predict(x_test)

# %%
dot_data = export_graphviz(clf, out_file=None, feature_names = data.feature_names, class_names = data.target_names)
graph = graphviz.Source(dot_data)

# %%
#graph

# %%
graph.render("BCP1")
# Out:
# 'BCP1.pdf'
